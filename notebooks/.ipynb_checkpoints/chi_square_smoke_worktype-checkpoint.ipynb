# %%
from os import path
from apsfinal.tables import ContigencyAgent
from scipy.stats import chi2_contingency
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: Set initial variables and initialize agent

# %%
csv_in = path.join('..', 'data', 'healthcare-dataset-stroke-data-cleanbmi.csv')  # Here, you can change the path you want
agent = ContigencyAgent(csv_in)

# %% [markdown]
# ### Step 2: Assign feature1 and feature2

# %%
# All feature names: gender, age, hypertension, heart_disease, ever_married, work_type,
#                    Residence_type, avg_glucose_level, bmi, smoking_status, stroke

# %%
feature1 = 'stroke' # top: stroke
feature2 = 'work_type' # left: age, work_type, avg_glucose_level, bmi, smoking_status

# %% [markdown]
# ### Step 3: Show Table

# %%
data_array = agent.show_contingency_table(feature1, feature2)
# Out:
# ╒═════════════════╤════════╤═══════════╤═══════════╕
# │                 │ Stroke │ No Stroke │ Row Total │
# ├─────────────────┼────────┼───────────┼───────────┤
# │ never smoked    │ 84     │ 1768      │ 1852      │
# ├─────────────────┼────────┼───────────┼───────────┤
# │ formerly smoked │ 57     │ 779       │ 836       │
# ├─────────────────┼────────┼───────────┼───────────┤
# │ smokes          │ 39     │ 698       │ 737       │
# ├─────────────────┼────────┼───────────┼───────────┤
# │ Column Total    │ 180    │ 3245      │ 3425      │
# ╘═════════════════╧════════╧═══════════╧═══════════╛
# X-square=6.03, df=2, p-value=4.906e-02

# %%
data_array, ex = agent.show_contingency_table_include_expected_values(feature1, feature2)
# Out:
# ╒═══════════════╤═════════════╤═══════════════╤═══════════╕
# │               │ Stroke      │ No Stroke     │ Row Total │
# ├───────────────┼─────────────┼───────────────┼───────────┤
# │ Private       │ 109 (118.5) │ 2091 (2081.5) │ 2200      │
# ├───────────────┼─────────────┼───────────────┼───────────┤
# │ Self-employed │ 48 (33.9)   │ 581 (595.1)   │ 629       │
# ├───────────────┼─────────────┼───────────────┼───────────┤
# │ Govt_job      │ 23 (27.7)   │ 491 (486.3)   │ 514       │
# ├───────────────┼─────────────┼───────────────┼───────────┤
# │ Column Total  │ 180         │ 3163          │ 3343      │
# ╘═══════════════╧═════════════╧═══════════════╧═══════════╛
# X-square=7.87, df=2, p-value=1.959e-02

# %%
fig, ax = plt.subplots(figsize=(5,5))

width = 1

prob1 = 109/2200
prob2 = 48/629
prob3 = 23/514
ax.bar(1, prob1, width, color="lightgreen", label=f"P(Stroke|Private)={prob1:.3f}")
ax.bar(3, prob2, width, color="pink",label=f"P(Stroke|Self-employed)={prob2:.3f}")
ax.bar(5, prob3, width, color="royalblue",label=f"P(Stroke|Govt_job)={prob3:.3f}")

ax.set_ylabel("P(Stroke|Work type)")
ax.set_xticks([1,3,5])
ax.set_xticklabels(["Private","Self-employed", "Govt_job"])
#ax.set_ylim(0,0.08)
ax.legend(bbox_to_anchor=[1, 1.25])

plt.tight_layout()
#plt.savefig("/home/yizaochen/Desktop/drawzone_temp/aps/condition_worktype.svg")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))

width = 1

prob1 = 84/1852
prob2 = 57/836
prob3 = 39/737
ax.bar(1, prob1, width, color="grey", label=f"P(Stroke|Never Smoke)={prob1:.3f}")
ax.bar(3, prob2, width, color="pink",label=f"P(Stroke|Formerly Smoke)={prob2:.3f}")
ax.bar(5, prob3, width, color="red",label=f"P(Stroke|Smoke)={prob3:.3f}")

ax.set_ylabel("P(Stroke|Smoking Status)")
ax.set_xticks([1,3,5])
ax.set_xticklabels(["Never Smoke","Formerly Smoke", "Smoke"])
#ax.set_ylim(0,0.08)
ax.legend(bbox_to_anchor=[1, 1.25])

plt.tight_layout()
#plt.savefig("/home/yizaochen/Desktop/drawzone_temp/aps/condition_smoke.svg")
plt.show()

# %% [markdown]
# ### Step 4: $\chi^2$ test

# %%
obs_list = list()
for col_id in range(len(['Stroke', 'No Stroke'])):
    obs_list.append(data_array[1:-1, col_id+1])
obs_array = np.array(obs_list)
obs_array
# Out:
# array([[20, 48, 47, 94, 40],
#        [2880, 786, 574, 475, 146]], dtype=object)

# %%
chi2_contingency(obs_array, correction=False)
# Out:
# (398.14772290638064,
#  6.990541750848635e-85,
#  4,
#  array([[ 141.3111546 ,   40.63913894,   30.26007828,   27.72622309,
#             9.06340509],
#         [2758.6888454 ,  793.36086106,  590.73992172,  541.27377691,
#           176.93659491]]))

# %%
obs = np.array([[10, 10, 20], [20, 20, 20]])
chi2, p, dof, ex = chi2_contingency(obs)
